# %%
import torch
import numpy as np
import blocks
import pandas as pd
from pathlib import Path
from dataloaders import Dataset_CTCovid19August2020
import matplotlib.pyplot as plt
from torchvision import transforms as tvtransforms
import transforms

# %%
dl = Dataset_CTCovid19August2020(Path("D:\data\CT-Covid-19-August2020\DRR_output\DRR_directory.csv"), Path("D:\data\CT-Covid-19-August2020\DRR_output"))
print(dl)
fig = plt.figure()

for i in range(len(dl)):
    sample = dl[i]

    print(i, sample['source'].shape, sample['boneless'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    plt.imshow(sample['source'])
    if i == 3:
        plt.show()
        break
# Out:
# ...
# 0 (341, 512) (341, 512)
# 1 (326, 512) (326, 512)
# 2 (321, 512) (321, 512)
# 3 (291, 512) (291, 512)

# %%
toTensor = transforms.ToTensor()
image_tensor = toTensor(sample['source'])

print(image_tensor.shape)

ss = transforms.StandardiseSize(256)
image = ss(image_tensor)

plt.imshow(image[0,0,:])
plt.show
# Out:
# torch.Size([1, 1, 291, 512])
# 256 256
# torch.Size([1, 1, 291, 512])
# <function matplotlib.pyplot.show>
